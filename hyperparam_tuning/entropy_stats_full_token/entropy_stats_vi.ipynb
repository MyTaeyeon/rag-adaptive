# %% [markdown]
# # Thống Kê Entropy (Tiếng Việt)
#
# Notebook này thu thập giá trị entropy từ các câu hỏi để xác định range của entropy phục vụ việc mapping.
#
# ## Cấu trúc:
# - **Cells 1-4**: Phần thu thập dữ liệu - Chạy một lần để thu thập và lưu kết quả
# - **Cells 5-7**: Phần phân tích - Có thể chạy độc lập bằng cách load CSV đã lưu
#
# ## Mục tiêu:
# 1. Load test queries từ file JSON
# 2. Thu thập entropy values sử dụng n=1 (để tiết kiệm API calls)
# 3. Lưu kết quả vào CSV cho phân tích sau
# 4. Load kết quả đã lưu và thực hiện thống kê/visualization

# %% [markdown]
# ## Cell 1: Setup và Import

# %%
import sys
import os
import json
from pathlib import Path

# Add project root to path
project_root = Path().absolute().parent.parent
sys.path.insert(0, str(project_root))

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
from typing import List, Dict

# Set matplotlib để xử lý font tiếng Việt
matplotlib.rcParams['font.family'] = 'DejaVu Sans'

print("Setup hoàn tất!")
# Out:
# Setup hoàn tất!

# %% [markdown]
# ## Cell 2: Import Modules và Load Queries

# %%
from backend.models.adaptive_controller import AdaptiveController
from backend.config.config import get_config

# Khởi tạo adaptive controller
config = get_config()
controller = AdaptiveController(
    k_min=config.adaptive.k_min,
    k_max=config.adaptive.k_max
)

# Load test queries từ JSON
queries_file = Path("test_queries_vi.json")
with open(queries_file, 'r', encoding='utf-8') as f:
    test_queries = json.load(f)

# Flatten queries thành list với categories
all_queries = []
for category, queries in test_queries.items():
    for query in queries:
        all_queries.append({
            'query': query,
            'difficulty': category
        })

print(f"Đã load {len(all_queries)} queries")
print(f"  - Dễ: {len([q for q in all_queries if q['difficulty'] == 'dễ'])}")
print(f"  - Trung bình: {len([q for q in all_queries if q['difficulty'] == 'trung_bình'])}")
print(f"  - Khó: {len([q for q in all_queries if q['difficulty'] == 'khó'])}")
print(f"\nSử dụng n_iterations = 1 để tiết kiệm API calls")
# Out:
# Đã load 101 queries
#   - Dễ: 34
#   - Trung bình: 34
#   - Khó: 33
#
# Sử dụng n_iterations = 1 để tiết kiệm API calls

# %% [markdown]
# ## Cell 3: Thu thập Entropy Data (n=1)

# %%
def collect_entropy_data(queries: List[Dict], language: str = "vi", n_iterations: int = 1) -> pd.DataFrame:
    """
    Thu thập entropy values từ các queries.
    Sử dụng n_iterations=1 để tiết kiệm API calls.
    
    Returns:
        DataFrame với columns: sample_id, query, difficulty, entropy
    """
    results = []
    
    print(f"Bắt đầu thu thập entropy với n_iterations={n_iterations}...")
    print(f"Tổng số queries: {len(queries)}\n")
    
    for idx, item in enumerate(queries, 1):
        query = item['query']
        difficulty = item['difficulty']
        
        print(f"[{idx}/{len(queries)}] {difficulty}: {query[:50]}...")
        
        try:
            # Chạy adaptive controller để lấy entropy
            k_determined, metadata = controller.decide(
                query=query,
                language=language,
                n=n_iterations
            )
            
            avg_entropy = metadata.get('average_entropy', 0.0)
            
            results.append({
                'sample_id': idx,
                'query': query,
                'difficulty': difficulty,
                'entropy': avg_entropy,
                'k_determined': k_determined
            })
            
        except Exception as e:
            print(f"    LỖI: {str(e)}")
            # Vẫn lưu record với lỗi
            results.append({
                'sample_id': idx,
                'query': query,
                'difficulty': difficulty,
                'entropy': None,
                'k_determined': None,
                'error': str(e)
            })
            continue
    
    return pd.DataFrame(results)

# Thu thập dữ liệu với n=1
df_entropy = collect_entropy_data(all_queries, language="vi", n_iterations=1)

print(f"\n✓ Đã thu thập {len(df_entropy)} samples")
df_entropy.head(10)
# Out:
# Bắt đầu thu thập entropy với n_iterations=1...
# Tổng số queries: 101
#
# [1/101] dễ: python là gì?...
# [2/101] dễ: git là gì?...
# [3/101] dễ: ai là gì?...
# [4/101] dễ: machine learning là gì?...
# [5/101] dễ: deep learning là gì?...
# [6/101] dễ: neural network là gì?...
# [7/101] dễ: gan là gì?...
# [8/101] dễ: transformer là gì?...
# [9/101] dễ: cơ sở dữ liệu là gì?...
# [10/101] dễ: thuật toán là gì?...
# [11/101] dễ: java là gì?...
# [12/101] dễ: javascript là gì?...
# [13/101] dễ: html là gì?...
# [14/101] dễ: css là gì?...
# [15/101] dễ: sql là gì?...
# [16/101] dễ: api là gì?...
# [17/101] dễ: json là gì?...
# [18/101] dễ: xml là gì?...
# [19/101] dễ: http là gì?...
# [20/101] dễ: https là gì?...
# [21/101] dễ: tcp là gì?...
# [22/101] dễ: ip là gì?...
# [23/101] dễ: dns là gì?...
# [24/101] dễ: cloud là gì?...
# [25/101] dễ: docker là gì?...
# [26/101] dễ: kubernetes là gì?...
# [27/101] dễ: linux là gì?...
# [28/101] dễ: windows là gì?...
# [29/101] dễ: macos là gì?...
# [30/101] dễ: ios là gì?...
# [31/101] dễ: android là gì?...
# [32/101] dễ: html5 là gì?...
# [33/101] dễ: css3 là gì?...
# [34/101] dễ: react là gì?...
# [35/101] trung_bình: so sánh machine learning và deep learning...
# [36/101] trung_bình: khác biệt giữa cnn và rnn...
# [37/101] trung_bình: khi nào nên dùng reinforcement learning...
# [38/101] trung_bình: ưu nhược điểm của transformer architecture...
# [39/101] trung_bình: cách hoạt động của attention mechanism...
# [40/101] trung_bình: gradient descent hoạt động như thế nào...
# [41/101] trung_bình: overfitting là gì và cách khắc phục...
# [42/101] trung_bình: khác biệt giữa supervised và unsupervised learning...
# [43/101] trung_bình: backpropagation hoạt động như thế nào...
# [44/101] trung_bình: activation function trong neural network là gì...
# [45/101] trung_bình: khác biệt giữa classification và regression...
# [46/101] trung_bình: giải thích cross-validation...
# [47/101] trung_bình: regularization trong machine learning là gì...
# [48/101] trung_bình: khác biệt giữa batch và stochastic gradient descen...
# [49/101] trung_bình: dropout hoạt động như thế nào...
# [50/101] trung_bình: giải thích batch normalization...
# [51/101] trung_bình: transfer learning là gì...
# [52/101] trung_bình: khác biệt giữa rnn và lstm...
# [53/101] trung_bình: convolutional layer hoạt động như thế nào...
# [54/101] trung_bình: giải thích pooling trong cnn...
# [55/101] trung_bình: data augmentation là gì...
# [56/101] trung_bình: khác biệt giữa precision và recall...
# [57/101] trung_bình: giải thích f1 score...
# [58/101] trung_bình: confusion matrix là gì...
# [59/101] trung_bình: k-means clustering hoạt động như thế nào...
# [60/101] trung_bình: khác biệt giữa random forest và gradient boosting...
# [61/101] trung_bình: giải thích feature selection...
# [62/101] trung_bình: dimensionality reduction là gì...
# [63/101] trung_bình: khác biệt giữa svm và logistic regression...
# [64/101] trung_bình: ensemble learning hoạt động như thế nào...
# [65/101] trung_bình: giải thích bias-variance tradeoff...
# [66/101] trung_bình: early stopping là gì...
# [67/101] trung_bình: khác biệt giữa validation và test set...
# [68/101] trung_bình: hyperparameter tuning hoạt động như thế nào...
# [69/101] khó: thiết kế một mô hình deep learning để xử lý văn bả...
# [70/101] khó: phân tích trade-off giữa model complexity và gener...
# [71/101] khó: giải thích chi tiết về backpropagation trong neura...
# [72/101] khó: so sánh các kiến trúc GAN hiện đại: StyleGAN, BigG...
# [73/101] khó: làm thế nào để optimize training của large languag...
# [74/101] khó: phân tích các kỹ thuật regularization trong deep l...
# [75/101] khó: thiết kế transformer architecture tối ưu cho ngôn ...
# [76/101] khó: giải thích nền tảng toán học của self-attention me...
# [77/101] khó: so sánh các thuật toán optimization: Adam, SGD, và...
# [78/101] khó: phân tích mối quan hệ giữa batch size, learning ra...
# [79/101] khó: thiết kế một hệ thống end-to-end cho real-time obj...
# [80/101] khó: giải thích cách xử lý class imbalance trong multi-...
# [81/101] khó: phân tích tác động của các loss functions khác nha...
# [82/101] khó: thiết kế một chiến lược neural architecture search...
# [83/101] khó: giải thích các nguyên tắc toán học đằng sau variat...
# [84/101] khó: so sánh các approaches khác nhau cho sequence-to-s...
# [85/101] khó: phân tích các challenges và solutions cho training...
# [86/101] khó: giải thích cách implement gradient clipping để pre...
# [87/101] khó: thiết kế một multi-task learning framework chia sẻ...
# [88/101] khó: phân tích các theoretical guarantees và limitation...
# [89/101] khó: giải thích cách sử dụng knowledge distillation để ...
# [90/101] khó: so sánh các approaches khác nhau để xử lý missing ...
# [91/101] khó: phân tích vai trò của các activation functions khá...
# [92/101] khó: thiết kế một federated learning system cho trainin...
# [93/101] khó: giải thích cách implement curriculum learning để i...
# [94/101] khó: so sánh các strategies khác nhau để xử lý imbalanc...
# [95/101] khó: phân tích tác động của các normalization technique...
# [96/101] khó: thiết kế một system cho online learning adapt với ...
# [97/101] khó: giải thích nền tảng toán học của generative advers...
# [98/101] khó: phân tích trade-offs giữa model interpretability v...
# [99/101] khó: thiết kế một neural architecture có thể xử lý cả i...
# [100/101] khó: giải thích cách implement continual learning để pr...
# [101/101] khó: so sánh các approaches khác nhau cho model compres...
#
# ✓ Đã thu thập 101 samples
#    sample_id                    query difficulty   entropy  k_determined
# 0          1            python là gì?         dễ  0.248757             0
# 1          2               git là gì?         dễ  0.286386             0
# 2          3                ai là gì?         dễ  0.221688             0
# 3          4  machine learning là gì?         dễ  0.337301             0
# 4          5     deep learning là gì?         dễ  0.315078             0
# 5          6    neural network là gì?         dễ  0.197860             0
# 6          7               gan là gì?         dễ  0.285329             0
# 7          8       transformer là gì?         dễ  0.198389             0
# 8          9     cơ sở dữ liệu là gì?         dễ  0.185609             0
# 9         10        thuật toán là gì?         dễ  0.252467             0

# %% [markdown]
# ## Cell 4: Lưu Kết Quả vào CSV

# %%
# Lưu kết quả vào CSV
csv_file = "entropy_analysis_results_vi.csv"
df_entropy.to_csv(csv_file, index=False)
print(f"✓ Kết quả đã lưu vào: {csv_file}")
print(f"Tổng số samples: {len(df_entropy)}")
df_entropy.head(10)
# Out:
# ✓ Kết quả đã lưu vào: entropy_analysis_results_vi.csv
# Tổng số samples: 101
#    sample_id                    query difficulty   entropy  k_determined
# 0          1            python là gì?         dễ  0.248757             0
# 1          2               git là gì?         dễ  0.286386             0
# 2          3                ai là gì?         dễ  0.221688             0
# 3          4  machine learning là gì?         dễ  0.337301             0
# 4          5     deep learning là gì?         dễ  0.315078             0
# 5          6    neural network là gì?         dễ  0.197860             0
# 6          7               gan là gì?         dễ  0.285329             0
# 7          8       transformer là gì?         dễ  0.198389             0
# 8          9     cơ sở dữ liệu là gì?         dễ  0.185609             0
# 9         10        thuật toán là gì?         dễ  0.252467             0

# %% [markdown]
# ## Cell 5: Đọc Kết Quả
#
# **Lưu ý:** Nếu bạn đã chạy xong phần thu thập dữ liệu (Cell 3) và đã lưu kết quả, bạn có thể bỏ qua Cells 1-4 và bắt đầu từ cell này để load kết quả đã lưu.

# %%
# Đọc kết quả từ file CSV
csv_file = "entropy_analysis_results_vi.csv"
df_entropy = pd.read_csv(csv_file)

print(f"✓ Đã load {len(df_entropy)} samples từ {csv_file}")
print(f"\nXem trước dữ liệu:")
df_entropy.head(10)
# Out:
# ✓ Đã load 101 samples từ entropy_analysis_results_vi.csv
#
# Xem trước dữ liệu:
#    sample_id                    query difficulty   entropy  k_determined
# 0          1            python là gì?         dễ  0.248757             0
# 1          2               git là gì?         dễ  0.286386             0
# 2          3                ai là gì?         dễ  0.221688             0
# 3          4  machine learning là gì?         dễ  0.337301             0
# 4          5     deep learning là gì?         dễ  0.315078             0
# 5          6    neural network là gì?         dễ  0.197860             0
# 6          7               gan là gì?         dễ  0.285329             0
# 7          8       transformer là gì?         dễ  0.198389             0
# 8          9     cơ sở dữ liệu là gì?         dễ  0.185609             0
# 9         10        thuật toán là gì?         dễ  0.252467             0

# %% [markdown]
# ## Cell 6: Thống Kê Cơ Bản

# %%
# Lọc các samples hợp lệ
df_valid = df_entropy[df_entropy['entropy'].notna()]

print("=== THỐNG KÊ CƠ BẢN ===\n")
print("Thống kê tổng quan:")
print(df_valid['entropy'].describe())
print(f"\nRange: [{df_valid['entropy'].min():.4f}, {df_valid['entropy'].max():.4f}]")

print("\nTheo độ khó:")
print(df_valid.groupby('difficulty')['entropy'].describe())

print("\nPercentiles:")
percentiles = [5, 10, 25, 50, 75, 90, 95, 99]
for p in percentiles:
    val = np.percentile(df_valid['entropy'], p)
    print(f"  {p}th percentile: {val:.4f}")
# Out:
# === THỐNG KÊ CƠ BẢN ===
#
# Thống kê tổng quan:
# count    101.000000
# mean       0.269083
# std        0.057712
# min        0.158441
# 25%        0.229774
# 50%        0.266736
# 75%        0.306171
# max        0.420658
# Name: entropy, dtype: float64
#
# Range: [0.1584, 0.4207]
#
# Theo độ khó:
#             count      mean       std       min       25%       50%       75%  \
# difficulty
# dễ           34.0  0.258317  0.062700  0.158441  0.215720  0.251708  0.284734
# khó          33.0  0.274793  0.059283  0.173279  0.231145  0.267865  0.326475
# trung_bình   34.0  0.274307  0.050733  0.183264  0.232959  0.270632  0.305117
#
#                  max
# difficulty
# dễ          0.414088
# khó         0.420658
# trung_bình  0.365461
#
# Percentiles:
#   5th percentile: 0.1822
#   10th percentile: 0.1979
#   25th percentile: 0.2298
#   50th percentile: 0.2667
#   75th percentile: 0.3062
#   90th percentile: 0.3427
#   95th percentile: 0.3641
#   99th percentile: 0.4141

# %% [markdown]
# ## Cell 7: Scatter Plot Visualization

# %%
# Lọc các samples hợp lệ
df_valid = df_entropy[df_entropy['entropy'].notna()]

# Color mapping: Red (dễ), Blue (trung_bình), Yellow (khó)
color_map = {
    'dễ': 'red',
    'trung_bình': 'blue',
    'khó': 'yellow'
}

# Tạo scatter plot
fig, ax = plt.subplots(figsize=(14, 8))

for difficulty in ['dễ', 'trung_bình', 'khó']:
    df_diff = df_valid[df_valid['difficulty'] == difficulty]
    if len(df_diff) > 0:
        ax.scatter(
            df_diff['sample_id'],
            df_diff['entropy'],
            c=color_map[difficulty],
            label=difficulty.capitalize().replace('_', ' '),
            alpha=0.6,
            s=50
        )

ax.set_xlabel('Sample ID', fontsize=12)
ax.set_ylabel('Entropy', fontsize=12)
ax.set_title('Entropy Distribution by Sample ID (Tiếng Việt)', fontsize=14, fontweight='bold')
ax.legend(fontsize=11)
ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

print(f"✓ Visualization hoàn tất")
print(f"  - Đỏ: Câu hỏi dễ ({len(df_valid[df_valid['difficulty'] == 'dễ'])} samples)")
print(f"  - Xanh: Câu hỏi trung bình ({len(df_valid[df_valid['difficulty'] == 'trung_bình'])} samples)")
print(f"  - Vàng: Câu hỏi khó ({len(df_valid[df_valid['difficulty'] == 'khó'])} samples)")
# Out:
# ✓ Visualization hoàn tất
#   - Đỏ: Câu hỏi dễ (34 samples)
#   - Xanh: Câu hỏi trung bình (34 samples)
#   - Vàng: Câu hỏi khó (33 samples)
